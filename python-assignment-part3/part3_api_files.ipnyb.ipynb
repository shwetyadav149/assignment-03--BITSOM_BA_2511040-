# %%
#TASK 1 — File Read & Write
file = open("python_notes.txt", "w", encoding="utf-8")

file.write("Topic 1: Variables store data. Python is dynamically typed.\n")
file.write("Topic 2: Lists are ordered and mutable.\n")
file.write("Topic 3: Dictionaries store key-value pairs.\n")
file.write("Topic 4: Loops automate repetitive tasks.\n")
file.write("Topic 5: Exception handling prevents crashes.\n")

file.close()

print("File written successfully.")
# Out:
# File written successfully.

# %%
file = open("python_notes.txt", "a", encoding="utf-8")

file.write("Topic 6: Functions help reuse code.\n")
file.write("Topic 7: Modules organize code.\n")

file.close()

print("Lines appended.")
# Out:
# Lines appended.

# %%
file = open("python_notes.txt", "r", encoding="utf-8")

lines = file.readlines()
file.close()

count = 0

for line in lines:
    count += 1
    print(f"{count}. {line.strip()}")

print("Total lines:", count)
# Out:
# 1. Topic 1: Variables store data. Python is dynamically typed.
# 2. Topic 2: Lists are ordered and mutable.
# 3. Topic 3: Dictionaries store key-value pairs.
# 4. Topic 4: Loops automate repetitive tasks.
# 5. Topic 5: Exception handling prevents crashes.
# 6. Topic 6: Functions help reuse code.
# 7. Topic 7: Modules organize code.
# Total lines: 7

# %%
keyword = input("Enter keyword: ").lower()

found = False

for line in lines:
    if keyword in line.lower():
        print(line.strip())
        found = True

if not found:
    print("No match found")
# Out:
# Topic 4: Loops automate repetitive tasks.

# %%
#TASK 2 — API Integrat
import requests

url = "https://dummyjson.com/products?limit=20"

response = requests.get(url)

data = response.json()

products = data["products"]

print("ID | Title | Price | Rating")

for p in products:
    print(p["id"], p["title"], p["price"], p["rating"])
# Out:
# ID | Title | Price | Rating
# 1 Essence Mascara Lash Princess 9.99 2.56
# 2 Eyeshadow Palette with Mirror 19.99 2.86
# 3 Powder Canister 14.99 4.64
# 4 Red Lipstick 12.99 4.36
# 5 Red Nail Polish 8.99 4.32
# 6 Calvin Klein CK One 49.99 4.37
# 7 Chanel Coco Noir Eau De 129.99 4.26
# 8 Dior J'adore 89.99 3.8
# 9 Dolce Shine Eau de 69.99 3.96
# 10 Gucci Bloom Eau de 79.99 2.74
# 11 Annibale Colombo Bed 1899.99 4.77
# 12 Annibale Colombo Sofa 2499.99 3.92
# 13 Bedside Table African Cherry 299.99 2.87
# 14 Knoll Saarinen Executive Conference Chair 499.99 4.88
# 15 Wooden Bathroom Sink With Mirror 799.99 3.59
# 16 Apple 1.99 4.19
# 17 Beef Steak 12.99 4.47
# 18 Cat Food 8.99 3.13
# 19 Chicken Meat 9.99 3.19
# 20 Cooking Oil 4.99 4.8

# %%
filtered = []

for p in products:
    if p["rating"] >= 4.5:
        filtered.append(p)

# sort by price descending
filtered.sort(key=lambda x: x["price"], reverse=True)

print("\nFiltered Products:")
for p in filtered:
    print(p["title"], p["price"], p["rating"])
# Out:
# Filtered Products:
# Annibale Colombo Bed 1899.99 4.77
# Knoll Saarinen Executive Conference Chair 499.99 4.88
# Powder Canister 14.99 4.64
# Cooking Oil 4.99 4.8

# %%
url = "https://dummyjson.com/products/category/laptops"

response = requests.get(url)
data = response.json()

print("\nLaptops:")

for p in data["products"]:
    print(p["title"], p["price"])
# Out:
# Laptops:
# Apple MacBook Pro 14 Inch Space Grey 1999.99
# Asus Zenbook Pro Dual Screen Laptop 1799.99
# Huawei Matebook X Pro 1399.99
# Lenovo Yoga 920 1099.99
# New DELL XPS 13 9300 Laptop 1499.99

# %%
url = "https://dummyjson.com/products/add"

new_product = {
    "title": "My Custom Product",
    "price": 999,
    "category": "electronics",
    "description": "A product I created via API"
}

response = requests.post(url, json=new_product)

print("\nPOST Response:")
print(response.json())
# Out:
# POST Response:
# {'id': 195, 'title': 'My Custom Product', 'price': 999, 'description': 'A product I created via API', 'category': 'electronics'}

# %%
# TASK 3 — Exception Handling
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Error: Cannot divide by zero"
    except TypeError:
        return "Error: Invalid input types"

print(safe_divide(10, 2))
print(safe_divide(10, 0))
print(safe_divide("ten", 2))
# Out:
# 5.0
# Error: Cannot divide by zero
# Error: Invalid input types

# %%
def read_file_safe(filename):
    try:
        file = open(filename, "r")
        data = file.read()
        file.close()
        return data
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    finally:
        print("File operation attempt complete.")

print(read_file_safe("python_notes.txt"))
print(read_file_safe("ghost_file.txt"))
# Out:
# File operation attempt complete.
# Topic 1: Variables store data. Python is dynamically typed.
# Topic 2: Lists are ordered and mutable.
# Topic 3: Dictionaries store key-value pairs.
# Topic 4: Loops automate repetitive tasks.
# Topic 5: Exception handling prevents crashes.
# Topic 6: Functions help reuse code.
# Topic 7: Modules organize code.
#
# Error: File 'ghost_file.txt' not found.
# File operation attempt complete.
# None

# %%
try:
    response = requests.get("https://dummyjson.com/products", timeout=5)
    print("API success")
except requests.exceptions.ConnectionError:
    print("Connection failed")
except requests.exceptions.Timeout:
    print("Request timed out")
except Exception as e:
    print("Error:", e)
# Out:
# API success

# %%
while True:
    user_input = input("Enter product ID (1–100) or quit: ")

    if user_input.lower() == "quit":
        break

    if not user_input.isdigit():
        print("Invalid input")
        continue

    pid = int(user_input)

    if pid < 1 or pid > 100:
        print("Out of range")
        continue

    url = f"https://dummyjson.com/products/{pid}"
    response = requests.get(url)

    if response.status_code == 404:
        print("Product not found")
    else:
        data = response.json()
        print(data["title"], data["price"])
# Out:
# Amazon Echo Plus 99.99
# Mug Tree Stand 15.99

# %%
# TASK 4 — Logging
from datetime import datetime

def log_error(message):
    file = open("error_log.txt", "a")
    time = datetime.now()
    file.write(f"[{time}] ERROR: {message}\n")
    file.close()

# %%
try:
    requests.get("https://this-host-does-not-exist-xyz.com/api")
except Exception as e:
    log_error(str(e))

# %%
response = requests.get("https://dummyjson.com/products/999")

if response.status_code != 200:
    log_error("404 Not Found for product ID 999")

# %%
file = open("error_log.txt", "r")
print(file.read())
file.close()
# Out:
# [2026-04-02 21:08:29.390144] ERROR: HTTPSConnectionPool(host='this-host-does-not-exist-xyz.com', port=443): Max retries exceeded with url: /api (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002EDA8CB6490>: Failed to resolve 'this-host-does-not-exist-xyz.com' ([Errno 11001] getaddrinfo failed)"))
# [2026-04-02 21:08:44.663736] ERROR: 404 Not Found for product ID 999
